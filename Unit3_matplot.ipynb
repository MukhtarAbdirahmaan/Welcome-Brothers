# %% [markdown]
# <a href="https://colab.research.google.com/github/MukhtarAbdirahmaan/Welcome-Brothers/blob/master/Unit3_matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing matplot lib
import matplotlib.pyplot as plt
#importing numpy
import numpy as np

# 31-02-2026----------------------Saturday ------------2:50 PM

# %%
#defining x and y list
x = [1,2,3,4,5]
y = [10,20,20,25,30]

# %%
# creating a line chart using x and y data
plt.plot(x,y)
plt.xlabel(" List X Values")
plt.ylabel(" List Y Values")
plt.title("Line Chart")
plt.show()

# %%
#defining two lists each contain subjects and subject marks
subjects = ["physcis" , "chemistry" , "Biology" , "Maths"]
marks= [76,89,66,45]

# %%
plt.bar(subjects,marks)
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("subject score compsrison Bar Chart")
# Out:
# Text(0.5, 1.0, 'subject score compsrison Bar Chart')

# %%
hours=[1,2,3,4,5]
scores=[50,55,65,70,85]

# %%
plt.scatter(hours,scores)
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.title("Relationship Studyhour and ToatlScore")
# Out:
# Text(0.5, 1.0, 'Relationship Studyhour and ToatlScore')

# %%
activities = ["study" , "Sleep" ,"Exercise","Entertainment"]
hours =[6,8,2,4]

# %%
plt.pie(hours , labels= activities, autopct="%1.1f%%")
plt.title("pie chart activities vs hours")
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/students.csv")

# %%
df.head()
# Out:
#   Student    Course  Score  Attendance
# 0     Ali  Database     78          90
# 1   Amina  Database     85          95
# 2  Hassan  Database     70          88
# 3  Fatima  Database     92          98
# 4    Omar  Database     65          80

# %%
df.tail()
# Out:
#    Student Course  Score  Attendance
# 15     Ali   Java     70          85
# 16   Amina   Java     83          94
# 17  Hassan   Java     68          82
# 18  Fatima   Java     90          96
# 19    Omar   Java     62          80

# %%
#calculating avg score by course
avg_score =df.groupby("Course")["Score"].mean()
avg_score
# Out:
# Course
# Database    78.0
# Java        74.6
# Python      80.6
# Web         74.8
# Name: Score, dtype: float64

# %%
#calculating avg Attandnce by course
avg_atd =df.groupby("Course")["Attendance"].mean()
avg_atd
# Out:
# Course
# Database    90.2
# Java        87.4
# Python      90.6
# Web         88.2
# Name: Attendance, dtype: float64

# %%
#number of students per course
students_per_course = df.groupby("Course")["Student"].count()
students_per_course
# Out:
# Course
# Database    5
# Java        5
# Python      5
# Web         5
# Name: Student, dtype: int64

# %%
avg_score.plot(kind="bar")
plt.xlabel("Course")
plt.ylabel("Average Score")
plt.title("Average Score by Course")
plt.show()

# %%
# Home Work in Line cahrt in matplot
avg_score.plot(kind='line')
plt.xlabel("Course")
plt.ylabel("Average Score")
plt.title("Average Score by Course")
plt.show()

# %%
# Drawing Histogram in Matplot
plt.hist(df["Score"])
# Out:
# (array([2., 1., 2., 3., 2., 1., 2., 2., 2., 3.]),
#  array([60. , 63.2, 66.4, 69.6, 72.8, 76. , 79.2, 82.4, 85.6, 88.8, 92. ]),
#  <BarContainer object of 10 artists>)
